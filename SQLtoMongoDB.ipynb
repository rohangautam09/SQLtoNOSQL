# %%
import pandas as pd
import cx_Oracle
import sqlalchemy

from sqlalchemy.exc import SQLAlchemyError
engine = sqlalchemy.create_engine("oracle+cx_oracle://VELDB60:VELDB60@indlin076/?service_name=VELABP1 ", arraysize=1000)
con = cx_Oracle.connect('VELDB60/VELDB60@indlin076:1521/VELABP1')
orders_sql = """SELECT * FROM subscriber"""; 
cursor = con.cursor()

df_sql = pd.read_sql(orders_sql, engine)
pd.set_option('display.max_columns', None)
df_sql
# Out:
#       subscriber_no   sys_creation_date     sys_update_date  operator_id  \
# 0                 1 2014-04-07 18:13:39 2017-02-15 15:02:07        107.0
# 1                21 2014-09-03 14:19:53 2017-09-19 13:24:51        107.0
# 2                63 2014-09-10 13:02:49 2016-05-16 16:44:26        107.0
# 3                81 2014-09-11 11:50:46 2019-08-02 12:28:58        106.0
# 4                82 2014-09-11 12:58:14 2016-05-16 16:44:17        107.0
# ...             ...                 ...                 ...          ...
# 3130          13603 2021-04-13 23:14:46 2021-04-13 23:46:30      41711.0
# 3131          13604 2021-04-14 00:09:10                 NaT      41711.0
# 3132          13605 2021-04-14 01:07:29 2021-04-14 09:51:45      41711.0
# 3133          13606 2021-04-14 10:33:32 2021-04-14 10:35:39      41711.0
# 3134          13607 2021-04-14 11:51:20 2021-04-14 14:37:52      41711.0
#
#      application_id dl_service_code  dl_update_stamp   sub_seq_no external_id  \
# ...

# %%
df_sql = df_sql.fillna("")
df_sql_dict = df_sql.to_dict(orient = "records")
df_sql_dict
# Out:
# [{'subscriber_no': 1,
#   'sys_creation_date': Timestamp('2014-04-07 18:13:39'),
#   'sys_update_date': Timestamp('2017-02-15 15:02:07'),
#   'operator_id': 107.0,
#   'application_id': 'CM    ',
#   'dl_service_code': 'CM017',
#   'dl_update_stamp': 5091.0,
#   'sub_seq_no': 200000000.0,
#   'external_id': '',
#   'customer_id': 1,
#   'ch_node_id': 2,
#   'effective_date': Timestamp('2014-04-02 23:59:59'),
#   'expiration_date': '',
#   'init_act_date': Timestamp('2020-02-27 12:31:12'),
#   'sub_status': 'C',
#   'sub_status_date': Timestamp('2020-02-25 00:00:00'),
#   'sub_sts_issue_date': Timestamp('2014-04-02 23:59:59'),
#   'sub_sts_last_act': '14',
#   'sub_sts_rsn_cd': 'AUDSB',
#   'dealer_code': 'DLR01   ',
#   'initial_dlr_code': 'DLR01   ',
#   'subscriber_type': 'LL',
#   'sub_password': '',
#   'prim_resource_tp': 'C',
#   'prim_resource_val': '9709810000',
#   'prim_res_param_cd': 'MSISDN',
#   'calc_pym_category': 'POST',
#   'ins_trx_id': 100000006.0,
# ...

# %%
import pymongo
import pandas as pd
import json
from pandas import DataFrame
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
db = client["Subscriber"]

# %%
#INSERTING DATAFRAME TO MONGODB

#db.Test_Subscriber.insert_many(df_sql_dict)

# %%
#CONVERTING MONGODB DATA INTO DATARAME

data_from_mongo = db.Test_Subscriber.find({},{'_id':0})
df_data_from_mongo = pd.DataFrame.from_dict(data_from_mongo)

df_data_from_mongo
# Out:
#       subscriber_no   sys_creation_date     sys_update_date operator_id  \
# 0                 1 2014-04-07 18:13:39 2017-02-15 15:02:07       107.0
# 1                21 2014-09-03 14:19:53 2017-09-19 13:24:51       107.0
# 2                63 2014-09-10 13:02:49 2016-05-16 16:44:26       107.0
# 3                81 2014-09-11 11:50:46 2019-08-02 12:28:58       106.0
# 4                82 2014-09-11 12:58:14 2016-05-16 16:44:17       107.0
# ...             ...                 ...                 ...         ...
# 3130          13603 2021-04-13 23:14:46 2021-04-13 23:46:30     41711.0
# 3131          13604 2021-04-14 00:09:10                 NaT     41711.0
# 3132          13605 2021-04-14 01:07:29 2021-04-14 09:51:45     41711.0
# 3133          13606 2021-04-14 10:33:32 2021-04-14 10:35:39     41711.0
# 3134          13607 2021-04-14 11:51:20 2021-04-14 14:37:52     41711.0
#
#      application_id dl_service_code dl_update_stamp   sub_seq_no external_id  \
# ...

# %%
rows = [tuple(x) for x in df_data_from_mongo.values]
#print(rows)
cursor.executemany("INSERT INTO subscriber_mark_1 VALUES (:1,:2,:3,:4)",rows)
#con_ora.commit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-32fbdda87d1c> in <module>
#       1 rows = [tuple(x) for x in df_data_from_mongo.values]
#       2 #print(rows)
# ----> 3 cursor.executemany("INSERT INTO subscriber_mark_1 VALUES (:1,:2,:3,:4)",rows)
#       4 #con_ora.commit()
#
# TypeError: expecting string or bytes object
